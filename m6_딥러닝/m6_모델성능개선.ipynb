# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 와인의 종류 예측하기
#
# - 속성 12개 : 주석산 농도, 아세트산 농도, 구연산 농도, 잔류 당분 농도, 염화나트륨 농도, 유리 아황산 농도, 총 아황산 농도, 밀도, pH, 황산칼륨 농도, 알코올 도수, 와인의 맛(0~10등급), 클래스(1:레드 와인, 0: 화이트 와인)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# 데이터를 입력합니다.
df = pd.read_csv('/content/drive/MyDrive/kdt_231026/m6_딥러닝/data/wine.csv')

# 데이터를 미리 보겠습니다.
df.head()
# Out:
#     7.4   0.7     0  1.9  0.076    11    34  0.9978  3.51  0.56  9.4  5  1
# 0   7.8  0.88  0.00  2.6  0.098  25.0  67.0  0.9968  3.20  0.68  9.8  5  1
# 1   7.8  0.76  0.04  2.3  0.092  15.0  54.0  0.9970  3.26  0.65  9.8  5  1
# 2  11.2  0.28  0.56  1.9  0.075  17.0  60.0  0.9980  3.16  0.58  9.8  6  1
# 3   7.4  0.70  0.00  1.9  0.076  11.0  34.0  0.9978  3.51  0.56  9.4  5  1
# 4   7.4  0.66  0.00  1.8  0.075  13.0  40.0  0.9978  3.51  0.56  9.4  5  1

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import random as python_random

tf.random.set_seed(123)
np.random.seed(123)
python_random.seed(123)

# 데이터를 입력합니다.
df = pd.read_csv('/content/drive/MyDrive/kdt_231026/m6_딥러닝/data/wine.csv', header=None)

# 와인의 속성을 X로 와인의 분류를 y로 저장합니다.
X = df.iloc[:,0:12]
y = df.iloc[:,12]

# 학습셋과 테스트셋으로 나눕니다.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)

# 모델 구조를 설정합니다.
model = Sequential()
model.add(Dense(30, input_dim = 12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation = 'relu'))
model.add(Dense(1, activation='sigmoid'))
# model.summary()

# 모델을 컴파일합니다.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델을 실행합니다.
history = model.fit(X_train, y_train,  epochs=50, batch_size=500, validation_split=0.25, verbose=0) # 검증셋 0.8 X 0.25 = 0.2

# 테스트 데이터를 사용하여 모델 평가
score = model.evaluate(X_test, y_test)
print(f'Test activation:', score[1])
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1663 - accuracy: 0.9400
# Test activation: 0.9399999976158142

# %% [markdown]
# ### seed 설정
# - NumPy의 무작위 작업에 대한 전역 제어를 위해 np.random.seed를 설정.
# - np.random.seed(123)를 설정해도 스크립트를 실행할 때마다 정확히 동일한 학습 평가데이터 분할이 재현되도록 보장하려는 경우 train_test_split과 같은 scikit-learn 함수에 random_state를 지정.
# - TensorFlow를 사용하는 경우 TensorFlow 작업에 tf.random.set_seed를 사용하며 신경망 레이어의 무작위 가중치 초기화, 훈련 프로세스의 임의성(예: , 이 특정 코드에 없는 드롭아웃 레이어를 사용하는 경우) 또는 임의성을 포함하는 기타 TensorFlow 작업을 사용하는 경우에 적용. 단순한 모델이나 특정 데이터 세트에 대해 훈련된 모델은 다양한 초기화에서 성능에 큰 변화를 나타내지 않을 수 있다
# - Python 내장 random 모듈이 스크립트의 어느 곳에서나 사용되는 경우 해당 모듈의 시드를 설정. TensorFlow 작업 자체에 'python_random.seed(123)'를 직접 사용할 필요가 없지만 스크립트 시작 부분에 python_random.seed(123)를 설정하면 난수 생성을 위해 내장된 python random 모듈을 사용하는 모든 Python 작업에 영향을 미칠 수 있다.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# 모델 저장의 조건을 설정합니다.
modelpath = '/content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/{epoch:02d}-{val_accuracy:.4f}.hdf5'
checkpointer = ModelCheckpoint(filepath=modelpath, verbose =1)

# 모델을 실행합니다.
history=model.fit(X_train, y_train, epochs=50, batch_size=500, validation_split=0.25, verbose=0, callbacks=[checkpointer])
# Out:
# Epoch 1: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/01-0.9323.hdf5
#
# Epoch 2: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/02-0.9331.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 3: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/03-0.9308.hdf5
#
# Epoch 4: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/04-0.9338.hdf5
#
# Epoch 5: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/05-0.9323.hdf5
#
# Epoch 6: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/06-0.9338.hdf5
#
# Epoch 7: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/07-0.9338.hdf5
#
# Epoch 8: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/08-0.9346.hdf5
#
# Epoch 9: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/09-0.9338.hdf5
#
# Epoch 10: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/10-0.9346.hdf5
#
# Epoch 11: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/11-0.9338.hdf5
#
# Epoch 12: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/12-0.9354.hdf5
#
# Epoch 13: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/13-0.9338.hdf5
#
# Epoch 14: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/14-0.9346.hdf5
#
# Epoch 15: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/15-0.9362.hdf5
#
# Epoch 16: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/16-0.9354.hdf5
#
# Epoch 17: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/17-0.9354.hdf5
#
# Epoch 18: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/18-0.9354.hdf5
#
# Epoch 19: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/19-0.9369.hdf5
#
# Epoch 20: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/20-0.9362.hdf5
#
# Epoch 21: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/21-0.9369.hdf5
#
# Epoch 22: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/22-0.9362.hdf5
#
# Epoch 23: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/23-0.9400.hdf5
#
# Epoch 24: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/24-0.9369.hdf5
#
# Epoch 25: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/25-0.9369.hdf5
#
# Epoch 26: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/26-0.9377.hdf5
#
# Epoch 27: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/27-0.9392.hdf5
#
# Epoch 28: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/28-0.9400.hdf5
#
# Epoch 29: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/29-0.9400.hdf5
#
# Epoch 30: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/30-0.9415.hdf5
#
# Epoch 31: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/31-0.9415.hdf5
#
# Epoch 32: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/32-0.9400.hdf5
#
# Epoch 33: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/33-0.9423.hdf5
#
# Epoch 34: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/34-0.9423.hdf5
#
# Epoch 35: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/35-0.9431.hdf5
#
# Epoch 36: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/36-0.9400.hdf5
#
# Epoch 37: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/37-0.9423.hdf5
#
# Epoch 38: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/38-0.9446.hdf5
#
# Epoch 39: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/39-0.9454.hdf5
#
# Epoch 40: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/40-0.9415.hdf5
#
# Epoch 41: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/41-0.9415.hdf5
#
# Epoch 42: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/42-0.9454.hdf5
#
# Epoch 43: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/43-0.9431.hdf5
#
# Epoch 44: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/44-0.9462.hdf5
#
# Epoch 45: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/45-0.9477.hdf5
#
# Epoch 46: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/46-0.9446.hdf5
#
# Epoch 47: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/47-0.9454.hdf5
#
# Epoch 48: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/48-0.9492.hdf5
#
# Epoch 49: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/49-0.9477.hdf5
#
# Epoch 50: saving model to /content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/all/50-0.9462.hdf5

# %%
# 테스트 결과를 출력합니다.
score = model.evaluate(X_test, y_test)
print(f'Test accuracy:', score[1])
# Out:
# 41/41 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.9477
# Test accuracy: 0.947692334651947

# %% [markdown]
# ### 그래프 과적합 확인하기

# %% [markdown]
# History 객체
#
# - 신경망 훈련을 위해 Keras 또는 TensorFlow 사용 시 model.fit()과 같은 호출로 훈련 작업을 실행하면 History 객체가 반환. 이 객체에는 연속적인 에포크의 훈련 손실 값과 측정항목 값 기록뿐만 아니라 해당하는 경우 검증 손실 값과 검증 측정항목 값도 포함.
# - 코드에서 얻은 History 객체의 내용을 보려면 훈련 과정 중에 기록된 측정항목이 포함된 사전인 history 속성에 액세스. 'history.history' 사전의 각 키는 훈련 중에 모니터링된 측정항목에 해당

# %%
# 그래프 확인을 위한 긴 학습 (컴퓨터 환경에 따라 시간이 다소 걸릴수 있습니다.)
history=model.fit(X_train, y_train, epochs=2000, batch_size=500, verbose=0, validation_split=0.25)

# %%
# Print the keys of the history object to understand what metrics are available
print(history.history.keys())

# To access a specific metric, for example, the training loss, you can do:
print(history.history['loss'])

# If you also have validation metrics, you can access them like this:
print(history.history['val_loss']) # For validation loss
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# [0.13058432936668396, 0.1310095489025116, 0.13138975203037262, 0.12948548793792725, 0.1321655511856079, 0.13071908056735992, 0.1321723759174347, 0.12746405601501465, 0.12532390654087067, 0.1270846426486969, 0.12571664154529572, 0.12375122308731079, 0.1230151578783989, 0.12178440392017365, 0.12137576192617416, 0.12072653323411942, 0.12016081064939499, 0.12039151787757874, 0.11880752444267273, 0.12066381424665451, 0.11743569374084473, 0.11724133789539337, 0.11630037426948547, 0.11
948631, 0.060134660452604294, 0.06071765720844269, 0.059698522090911865, 0.06235486641526222, 0.06356658041477203, 0.06609191745519638, 0.06228993833065033, 0.059193674474954605, 0.06365001946687698, 0.062047652900218964, 0.059914056211709976, 0.05964984744787216, 0.0640149712562561, 0.05905813351273537, 0.0597514808177948, 0.062227699905633926, 0.0676809549331665, 0.0642920508980751, 0.06736390292644501, 0.06924686580896378, 0.05940445512533188, 0.05781681835651398, 0.05879919230937958, 0.057838164269924164, 0.05865650996565819, 0.06957689672708511, 0.07857485860586166, 0.07414640486240387, 0.059223245829343796, 0.059863388538360596, 0.061851631850004196, 0.062338270246982574, 0.06302420794963837, 0.06760820746421814, 0.06 ...

# %%
# history에 저장된 학습 결과를 확인해 보겠습니다.
hist_df = pd.DataFrame(history.history)
hist_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  0.130584  0.952014  0.130970      0.949231
# 1  0.131010  0.955094  0.128787      0.944615
# 2  0.131390  0.950731  0.127585      0.949231
# 3  0.129485  0.951245  0.130339      0.950769
# 4  0.132166  0.952784  0.127695      0.946923

# %%
import matplotlib.pyplot as plt
# y_vloss에 테스트셋(여기서는 검증셋)의 오차를 저장합니다.
y_vloss=hist_df['val_loss']

# y_loss에 학습셋의 오차를 저장합니다.
y_loss=hist_df['loss']

# x 값을 저장하고 테스트셋(검증셋)의 오차를 빨간색으로, 학습셋의 오차를 파란색으로 표시합니다.
x_len = np.arange(len(y_loss))
plt.plot(x_len, y_vloss, "o", c='red', markersize=2, label='Validation loss')
plt.plot(x_len, y_loss, "o", c='blue', markersize=2, label='Training loss')

plt.legend(loc='upper right')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import os
import pandas as pd
import random as python_random

np.random.seed(123)  # Numpy module.
python_random.seed(123)  # Python random module.
tf.random.set_seed(123)  # TensorFlow module.

# 데이터를 입력합니다.
df = pd.read_csv('/content/drive/MyDrive/kdt_231026/m6_딥러닝/data/wine.csv', header=None)

# 와인의 속성을 X로 와인의 분류를 y로 저장합니다.
X = df.iloc[:,0:12]
y = df.iloc[:,12]

#학습셋과 테스트셋으로 나눕니다.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=0)

# 모델 구조를 설정합니다.
model = Sequential()
model.add(Dense(30,  input_dim=12, activation='relu'))
model.add(Dense(12, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.summary()

#모델을 컴파일합니다.
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_35 (Dense)            (None, 30)                390
#
#  dense_36 (Dense)            (None, 12)                372
#
#  dense_37 (Dense)            (None, 8)                 104
#
#  dense_38 (Dense)            (None, 1)                 9
#
# =================================================================
# Total params: 875 (3.42 KB)
# Trainable params: 875 (3.42 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# [ callback ]
#
# callbacks=[early_stopping_callback, checkpointer]
#
# 학습 과정 중에 특정 이벤트가 발생했을 때, 취할 행동을 정의.
#
# - early_stopping_callback: 이 콜백은 모델의 성능이 더 이상 개선되지 않을 때 학습을 조기에 중단하도록 설정. 예를 들어, 검증 데이터에 대한 손실이 일정 기간 동안 개선되지 않으면 학습을 멈춘다. 이는 과적합을 방지하고 학습 시간을 단축시키는 데 도움이 된다.
# - checkpointer: 이 콜백은 모델의 중간 학습 상태를 파일로 저장하여, 학습 과정에서 가장 좋은 모델을 보존할 수 있게 한다. 이를 통해 나중에 모델을 재사용하거나, 학습 과정이 끝난 후 최적의 모델 상태로 복원할 수 있다.
#
# 이 코드는 신경망 모델의 학습 과정을 세밀하게 제어하면서, 과적합을 방지하고, 학습 과정에서 모델의 최적 상태를 저장하는 방법을 보여준다.

# %% [markdown]
# ## 학습의 자동 중단 및 최적화 모델 저장

# %%
# 학습이 언제 자동 중단 될지를 설정합니다.
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=30)

# 최적화 모델에 저장될 폴더와 모델의 이름을 정합니다.
modelpath='/content/drive/MyDrive/kdt_231026/m6_딥러닝/data/model/bestmodel.hdf5'

# 최적화 모델을 업데이트하고 저장합니다.
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=0, save_best_only=True)

# 모델을 실행합니다.
history = model.fit(X_train, y_train, epochs=2000, batch_size=500, validation_split=0.25,
                  verbose = 1, callbacks = [early_stopping_callback,checkpointer])
# Out:
# Epoch 1/2000
# 1/8 [==>...........................] - ETA: 0s - loss: 0.0423 - accuracy: 0.9860
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 8/8 [==============================] - 1s 121ms/step - loss: 0.0538 - accuracy: 0.9828 - val_loss: 0.0614 - val_accuracy: 0.9815
# Epoch 2/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0548 - accuracy: 0.9833 - val_loss: 0.0787 - val_accuracy: 0.9762
# Epoch 3/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0594 - accuracy: 0.9810 - val_loss: 0.0610 - val_accuracy: 0.9808
# Epoch 4/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0527 - accuracy: 0.9836 - val_loss: 0.0711 - val_accuracy: 0.9808
# Epoch 5/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0598 - accuracy: 0.9802 - val_loss: 0.0681 - val_accuracy: 0.9808
# Epoch 6/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0533 - accuracy: 0.9838 - val_loss: 0.0565 - val_accuracy: 0.9831
# Epoch 7/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0572 - accuracy: 0.9826 - val_loss: 0.0610 - val_accuracy: 0.9808
# Epoch 8/2000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0574 - accuracy: 0.9818 - val_loss: 0.0569 - val_accuracy: 0.9815
# Epoch 9/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0533 - accuracy: 0.9841 - val_loss: 0.0578 - val_accuracy: 0.9808
# Epoch 10/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0539 - accuracy: 0.9833 - val_loss: 0.0605 - val_accuracy: 0.9808
# Epoch 11/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0571 - accuracy: 0.9823 - val_loss: 0.0572 - val_accuracy: 0.9815
# Epoch 12/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0527 - accuracy: 0.9828 - val_loss: 0.0572 - val_accuracy: 0.9838
# Epoch 13/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0537 - accuracy: 0.9826 - val_loss: 0.0594 - val_accuracy: 0.9831
# Epoch 14/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0523 - accuracy: 0.9820 - val_loss: 0.0576 - val_accuracy: 0.9838
# Epoch 15/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0516 - accuracy: 0.9841 - val_loss: 0.0586 - val_accuracy: 0.9831
# Epoch 16/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0525 - accuracy: 0.9831 - val_loss: 0.0572 - val_accuracy: 0.9838
# Epoch 17/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0546 - accuracy: 0.9836 - val_loss: 0.0645 - val_accuracy: 0.9823
# Epoch 18/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0578 - accuracy: 0.9815 - val_loss: 0.0567 - val_accuracy: 0.9815
# Epoch 19/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0553 - accuracy: 0.9826 - val_loss: 0.0604 - val_accuracy: 0.9808
# Epoch 20/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0603 - accuracy: 0.9813 - val_loss: 0.0612 - val_accuracy: 0.9815
# Epoch 21/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0600 - accuracy: 0.9823 - val_loss: 0.0626 - val_accuracy: 0.9815
# Epoch 22/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0579 - accuracy: 0.9818 - val_loss: 0.0574 - val_accuracy: 0.9838
# Epoch 23/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0566 - accuracy: 0.9836 - val_loss: 0.0563 - val_accuracy: 0.9838
# Epoch 24/2000
# 8/8 [==============================] - 0s 15ms/step - loss: 0.0530 - accuracy: 0.9836 - val_loss: 0.0557 - val_accuracy: 0.9831
# Epoch 25/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0527 - accuracy: 0.9843 - val_loss: 0.0556 - val_accuracy: 0.9831
# Epoch 26/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0525 - accuracy: 0.9843 - val_loss: 0.0560 - val_accuracy: 0.9831
# Epoch 27/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0523 - accuracy: 0.9841 - val_loss: 0.0568 - val_accuracy: 0.9800
# Epoch 28/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0526 - accuracy: 0.9831 - val_loss: 0.0577 - val_accuracy: 0.9838
# Epoch 29/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0509 - accuracy: 0.9843 - val_loss: 0.0561 - val_accuracy: 0.9831
# Epoch 30/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0542 - accuracy: 0.9823 - val_loss: 0.0561 - val_accuracy: 0.9831
# Epoch 31/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0552 - accuracy: 0.9808 - val_loss: 0.0559 - val_accuracy: 0.9831
# Epoch 32/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0527 - accuracy: 0.9836 - val_loss: 0.0558 - val_accuracy: 0.9831
# Epoch 33/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0520 - accuracy: 0.9833 - val_loss: 0.0579 - val_accuracy: 0.9838
# Epoch 34/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0513 - accuracy: 0.9836 - val_loss: 0.0562 - val_accuracy: 0.9838
# Epoch 35/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0508 - accuracy: 0.9831 - val_loss: 0.0558 - val_accuracy: 0.9831
# Epoch 36/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0502 - accuracy: 0.9833 - val_loss: 0.0576 - val_accuracy: 0.9838
# Epoch 37/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0506 - accuracy: 0.9838 - val_loss: 0.0589 - val_accuracy: 0.9831
# Epoch 38/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0513 - accuracy: 0.9838 - val_loss: 0.0563 - val_accuracy: 0.9823
# Epoch 39/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0546 - accuracy: 0.9820 - val_loss: 0.0559 - val_accuracy: 0.9838
# Epoch 40/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0522 - accuracy: 0.9843 - val_loss: 0.0583 - val_accuracy: 0.9838
# Epoch 41/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0507 - accuracy: 0.9841 - val_loss: 0.0568 - val_accuracy: 0.9838
# Epoch 42/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0505 - accuracy: 0.9841 - val_loss: 0.0616 - val_accuracy: 0.9815
# Epoch 43/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0511 - accuracy: 0.9849 - val_loss: 0.0579 - val_accuracy: 0.9838
# Epoch 44/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0504 - accuracy: 0.9849 - val_loss: 0.0573 - val_accuracy: 0.9815
# Epoch 45/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0508 - accuracy: 0.9843 - val_loss: 0.0601 - val_accuracy: 0.9815
# Epoch 46/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0531 - accuracy: 0.9841 - val_loss: 0.0609 - val_accuracy: 0.9823
# Epoch 47/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0518 - accuracy: 0.9851 - val_loss: 0.0569 - val_accuracy: 0.9838
# Epoch 48/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0505 - accuracy: 0.9841 - val_loss: 0.0637 - val_accuracy: 0.9815
# Epoch 49/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0518 - accuracy: 0.9836 - val_loss: 0.0601 - val_accuracy: 0.9823
# Epoch 50/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0508 - accuracy: 0.9849 - val_loss: 0.0581 - val_accuracy: 0.9831
# Epoch 51/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0502 - accuracy: 0.9851 - val_loss: 0.0557 - val_accuracy: 0.9838
# Epoch 52/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0503 - accuracy: 0.9843 - val_loss: 0.0560 - val_accuracy: 0.9838
# Epoch 53/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0497 - accuracy: 0.9846 - val_loss: 0.0560 - val_accuracy: 0.9838
# Epoch 54/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0508 - accuracy: 0.9836 - val_loss: 0.0558 - val_accuracy: 0.9838
# Epoch 55/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0499 - accuracy: 0.9841 - val_loss: 0.0555 - val_accuracy: 0.9838
# Epoch 56/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0499 - accuracy: 0.9841 - val_loss: 0.0556 - val_accuracy: 0.9838
# Epoch 57/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0511 - accuracy: 0.9841 - val_loss: 0.0609 - val_accuracy: 0.9831
# Epoch 58/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0513 - accuracy: 0.9838 - val_loss: 0.0580 - val_accuracy: 0.9838
# Epoch 59/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0505 - accuracy: 0.9851 - val_loss: 0.0559 - val_accuracy: 0.9831
# Epoch 60/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0509 - accuracy: 0.9843 - val_loss: 0.0566 - val_accuracy: 0.9838
# Epoch 61/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0514 - accuracy: 0.9856 - val_loss: 0.0582 - val_accuracy: 0.9838
# Epoch 62/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0496 - accuracy: 0.9849 - val_loss: 0.0557 - val_accuracy: 0.9838
# Epoch 63/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0506 - accuracy: 0.9836 - val_loss: 0.0656 - val_accuracy: 0.9823
# Epoch 64/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0519 - accuracy: 0.9851 - val_loss: 0.0667 - val_accuracy: 0.9823
# Epoch 65/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0495 - accuracy: 0.9849 - val_loss: 0.0559 - val_accuracy: 0.9838
# Epoch 66/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0494 - accuracy: 0.9846 - val_loss: 0.0564 - val_accuracy: 0.9800
# Epoch 67/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0506 - accuracy: 0.9828 - val_loss: 0.0560 - val_accuracy: 0.9838
# Epoch 68/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0496 - accuracy: 0.9843 - val_loss: 0.0585 - val_accuracy: 0.9831
# Epoch 69/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0503 - accuracy: 0.9846 - val_loss: 0.0577 - val_accuracy: 0.9838
# Epoch 70/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0501 - accuracy: 0.9849 - val_loss: 0.0559 - val_accuracy: 0.9838
# Epoch 71/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0493 - accuracy: 0.9843 - val_loss: 0.0557 - val_accuracy: 0.9838
# Epoch 72/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0498 - accuracy: 0.9846 - val_loss: 0.0573 - val_accuracy: 0.9838
# Epoch 73/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0492 - accuracy: 0.9856 - val_loss: 0.0560 - val_accuracy: 0.9808
# Epoch 74/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0509 - accuracy: 0.9861 - val_loss: 0.0565 - val_accuracy: 0.9808
# Epoch 75/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0525 - accuracy: 0.9859 - val_loss: 0.0556 - val_accuracy: 0.9831
# Epoch 76/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0496 - accuracy: 0.9838 - val_loss: 0.0563 - val_accuracy: 0.9838
# Epoch 77/2000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0491 - accuracy: 0.9849 - val_loss: 0.0555 - val_accuracy: 0.9838
# Epoch 78/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0534 - accuracy: 0.9841 - val_loss: 0.0556 - val_accuracy: 0.9808
# Epoch 79/2000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0530 - accuracy: 0.9846 - val_loss: 0.0553 - val_accuracy: 0.9838
# Epoch 80/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0504 - accuracy: 0.9833 - val_loss: 0.0555 - val_accuracy: 0.9838
# Epoch 81/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0533 - accuracy: 0.9843 - val_loss: 0.0569 - val_accuracy: 0.9838
# Epoch 82/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0539 - accuracy: 0.9833 - val_loss: 0.0590 - val_accuracy: 0.9815
# Epoch 83/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0494 - accuracy: 0.9838 - val_loss: 0.0601 - val_accuracy: 0.9823
# Epoch 84/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0501 - accuracy: 0.9851 - val_loss: 0.0555 - val_accuracy: 0.9838
# Epoch 85/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0499 - accuracy: 0.9846 - val_loss: 0.0558 - val_accuracy: 0.9808
# Epoch 86/2000
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0524 - accuracy: 0.9854 - val_loss: 0.0576 - val_accuracy: 0.9815
# Epoch 87/2000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0531 - accuracy: 0.9828 - val_loss: 0.0550 - val_accuracy: 0.9846
# Epoch 88/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0567 - accuracy: 0.9815 - val_loss: 0.0593 - val_accuracy: 0.9823
# Epoch 89/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0563 - accuracy: 0.9826 - val_loss: 0.0734 - val_accuracy: 0.9800
# Epoch 90/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0535 - accuracy: 0.9828 - val_loss: 0.0574 - val_accuracy: 0.9838
# Epoch 91/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0493 - accuracy: 0.9841 - val_loss: 0.0577 - val_accuracy: 0.9823
# Epoch 92/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0508 - accuracy: 0.9843 - val_loss: 0.0721 - val_accuracy: 0.9808
# Epoch 93/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0558 - accuracy: 0.9823 - val_loss: 0.0757 - val_accuracy: 0.9808
# Epoch 94/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0572 - accuracy: 0.9823 - val_loss: 0.0641 - val_accuracy: 0.9823
# Epoch 95/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0548 - accuracy: 0.9836 - val_loss: 0.0554 - val_accuracy: 0.9838
# Epoch 96/2000
# 8/8 [==============================] - 0s 13ms/step - loss: 0.0484 - accuracy: 0.9846 - val_loss: 0.0598 - val_accuracy: 0.9815
# Epoch 97/2000
# 8/8 [==============================] - 0s 21ms/step - loss: 0.0527 - accuracy: 0.9833 - val_loss: 0.0550 - val_accuracy: 0.9838
# Epoch 98/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0524 - accuracy: 0.9833 - val_loss: 0.0552 - val_accuracy: 0.9808
# Epoch 99/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0525 - accuracy: 0.9838 - val_loss: 0.0554 - val_accuracy: 0.9831
# Epoch 100/2000
# 8/8 [==============================] - 0s 11ms/step - loss: 0.0528 - accuracy: 0.9838 - val_loss: 0.0580 - val_accuracy: 0.9815
# Epoch 101/2000
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0517 - accuracy: 0.9851 - val_loss: 0.0566 - val_accuracy: 0.9823
# Epoch 102/2000
# 8/8 [==============================] - 0s 14ms/step - loss: 0.0519 - accuracy: 0.9836 - val_loss: 0.0645 - val_accuracy: 0.9792
# Epoch 103/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0549 - accuracy: 0.9833 - val_loss: 0.0625 - val_accuracy: 0.9808
# Epoch 104/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0538 - accuracy: 0.9831 - val_loss: 0.0609 - val_accuracy: 0.9808
# Epoch 105/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0558 - accuracy: 0.9826 - val_loss: 0.0597 - val_accuracy: 0.9808
# Epoch 106/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0499 - accuracy: 0.9851 - val_loss: 0.0556 - val_accuracy: 0.9831
# Epoch 107/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0491 - accuracy: 0.9851 - val_loss: 0.0555 - val_accuracy: 0.9838
# Epoch 108/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0539 - accuracy: 0.9818 - val_loss: 0.0553 - val_accuracy: 0.9838
# Epoch 109/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0490 - accuracy: 0.9851 - val_loss: 0.0661 - val_accuracy: 0.9792
# Epoch 110/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0627 - accuracy: 0.9805 - val_loss: 0.0679 - val_accuracy: 0.9777
# Epoch 111/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0540 - accuracy: 0.9838 - val_loss: 0.0593 - val_accuracy: 0.9815
# Epoch 112/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0517 - accuracy: 0.9846 - val_loss: 0.0560 - val_accuracy: 0.9823
# Epoch 113/2000
# 8/8 [==============================] - 0s 18ms/step - loss: 0.0517 - accuracy: 0.9838 - val_loss: 0.0547 - val_accuracy: 0.9831
# Epoch 114/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0488 - accuracy: 0.9859 - val_loss: 0.0554 - val_accuracy: 0.9808
# Epoch 115/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0495 - accuracy: 0.9846 - val_loss: 0.0550 - val_accuracy: 0.9831
# Epoch 116/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0508 - accuracy: 0.9836 - val_loss: 0.0565 - val_accuracy: 0.9815
# Epoch 117/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0500 - accuracy: 0.9838 - val_loss: 0.0556 - val_accuracy: 0.9846
# Epoch 118/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0479 - accuracy: 0.9849 - val_loss: 0.0555 - val_accuracy: 0.9838
# Epoch 119/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0484 - accuracy: 0.9856 - val_loss: 0.0616 - val_accuracy: 0.9823
# Epoch 120/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0492 - accuracy: 0.9851 - val_loss: 0.0590 - val_accuracy: 0.9823
# Epoch 121/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0501 - accuracy: 0.9843 - val_loss: 0.0580 - val_accuracy: 0.9838
# Epoch 122/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0491 - accuracy: 0.9851 - val_loss: 0.0589 - val_accuracy: 0.9823
# Epoch 123/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0511 - accuracy: 0.9846 - val_loss: 0.0631 - val_accuracy: 0.9815
# Epoch 124/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0513 - accuracy: 0.9826 - val_loss: 0.0835 - val_accuracy: 0.9769
# Epoch 125/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0664 - accuracy: 0.9777 - val_loss: 0.0660 - val_accuracy: 0.9815
# Epoch 126/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0519 - accuracy: 0.9846 - val_loss: 0.0600 - val_accuracy: 0.9831
# Epoch 127/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0492 - accuracy: 0.9841 - val_loss: 0.0585 - val_accuracy: 0.9838
# Epoch 128/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0474 - accuracy: 0.9872 - val_loss: 0.0549 - val_accuracy: 0.9831
# Epoch 129/2000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0490 - accuracy: 0.9851 - val_loss: 0.0608 - val_accuracy: 0.9831
# Epoch 130/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0498 - accuracy: 0.9838 - val_loss: 0.0664 - val_accuracy: 0.9815
# Epoch 131/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0500 - accuracy: 0.9851 - val_loss: 0.0550 - val_accuracy: 0.9846
# Epoch 132/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0528 - accuracy: 0.9826 - val_loss: 0.0665 - val_accuracy: 0.9823
# Epoch 133/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0540 - accuracy: 0.9831 - val_loss: 0.0662 - val_accuracy: 0.9823
# Epoch 134/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0503 - accuracy: 0.9833 - val_loss: 0.0680 - val_accuracy: 0.9815
# Epoch 135/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0504 - accuracy: 0.9841 - val_loss: 0.0612 - val_accuracy: 0.9823
# Epoch 136/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0514 - accuracy: 0.9846 - val_loss: 0.0566 - val_accuracy: 0.9838
# Epoch 137/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0481 - accuracy: 0.9851 - val_loss: 0.0554 - val_accuracy: 0.9838
# Epoch 138/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0475 - accuracy: 0.9854 - val_loss: 0.0560 - val_accuracy: 0.9846
# Epoch 139/2000
# 8/8 [==============================] - 0s 12ms/step - loss: 0.0487 - accuracy: 0.9846 - val_loss: 0.0545 - val_accuracy: 0.9846
# Epoch 140/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0479 - accuracy: 0.9851 - val_loss: 0.0545 - val_accuracy: 0.9838
# Epoch 141/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0479 - accuracy: 0.9849 - val_loss: 0.0550 - val_accuracy: 0.9846
# Epoch 142/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0472 - accuracy: 0.9856 - val_loss: 0.0548 - val_accuracy: 0.9846
# Epoch 143/2000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0488 - accuracy: 0.9831 - val_loss: 0.0557 - val_accuracy: 0.9808
# Epoch 144/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0480 - accuracy: 0.9849 - val_loss: 0.0569 - val_accuracy: 0.9838
# Epoch 145/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0515 - accuracy: 0.9841 - val_loss: 0.0584 - val_accuracy: 0.9838
# Epoch 146/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0525 - accuracy: 0.9854 - val_loss: 0.0715 - val_accuracy: 0.9823
# Epoch 147/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0537 - accuracy: 0.9826 - val_loss: 0.0605 - val_accuracy: 0.9838
# Epoch 148/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0564 - accuracy: 0.9820 - val_loss: 0.0574 - val_accuracy: 0.9846
# Epoch 149/2000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0515 - accuracy: 0.9831 - val_loss: 0.0559 - val_accuracy: 0.9831
# Epoch 150/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0491 - accuracy: 0.9843 - val_loss: 0.0556 - val_accuracy: 0.9831
# Epoch 151/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0509 - accuracy: 0.9843 - val_loss: 0.0579 - val_accuracy: 0.9846
# Epoch 152/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0480 - accuracy: 0.9846 - val_loss: 0.0563 - val_accuracy: 0.9823
# Epoch 153/2000
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0523 - accuracy: 0.9836 - val_loss: 0.0554 - val_accuracy: 0.9808
# Epoch 154/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0486 - accuracy: 0.9854 - val_loss: 0.0608 - val_accuracy: 0.9823
# Epoch 155/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0486 - accuracy: 0.9849 - val_loss: 0.0618 - val_accuracy: 0.9823
# Epoch 156/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0470 - accuracy: 0.9859 - val_loss: 0.0545 - val_accuracy: 0.9838
# Epoch 157/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0479 - accuracy: 0.9854 - val_loss: 0.0548 - val_accuracy: 0.9815
# Epoch 158/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0479 - accuracy: 0.9856 - val_loss: 0.0564 - val_accuracy: 0.9823
# Epoch 159/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0509 - accuracy: 0.9854 - val_loss: 0.0574 - val_accuracy: 0.9823
# Epoch 160/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0523 - accuracy: 0.9851 - val_loss: 0.0550 - val_accuracy: 0.9831
# Epoch 161/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0488 - accuracy: 0.9846 - val_loss: 0.0552 - val_accuracy: 0.9846
# Epoch 162/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0482 - accuracy: 0.9851 - val_loss: 0.0555 - val_accuracy: 0.9846
# Epoch 163/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0485 - accuracy: 0.9861 - val_loss: 0.0581 - val_accuracy: 0.9846
# Epoch 164/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0475 - accuracy: 0.9843 - val_loss: 0.0574 - val_accuracy: 0.9846
# Epoch 165/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0500 - accuracy: 0.9856 - val_loss: 0.0551 - val_accuracy: 0.9846
# Epoch 166/2000
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0603 - accuracy: 0.9787 - val_loss: 0.0581 - val_accuracy: 0.9823
# Epoch 167/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0524 - accuracy: 0.9833 - val_loss: 0.0587 - val_accuracy: 0.9823
# Epoch 168/2000
# 8/8 [==============================] - 0s 10ms/step - loss: 0.0493 - accuracy: 0.9856 - val_loss: 0.0571 - val_accuracy: 0.9823
# Epoch 169/2000
# 8/8 [==============================] - 0s 8ms/step - loss: 0.0476 - accuracy: 0.9856 - val_loss: 0.0557 - val_accuracy: 0.9846

# %%
# 테스트 결과를 출력합니다.
score = model.evaluate(X_test, y_test)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 0.947692334651947

# %%
# history 객체에서 학습셋과 정확도를 가져옵니다.
# 'acc' 대신  'accuracy'를 사용해야 할 수도 있습니다. 이는 keras 버전에 따라 다릅니다.
y_acc = history.history['accuracy'] # 'acc' 대신 'accuracy'를 사용하는 경우가 있습니다.
y_val_acc = history.history['val_accuracy'] # 마찬가지로 'val_accuracy'를 사용

# x 값을 지정합니다.
x_len = np.arange(len(y_acc))

# 검증셋의 정확도를 빨간색으로, 학습셋의 정확도를 파란색으로 표시합니다.
plt.plot(x_len, y_val_acc, "o", c='red', markersize=2, label='Validation Accuracy')
plt.plot(x_len, y_acc, "o", c='blue', markersize=2, label='Training Accuracy')

# 범례와 축 라벨을 추가합니다.
plt.legend(loc='upper left')
plt.xlim(0, len(y_acc)-1)
plt.ylim(0.95, 1.0)
plt.xlabel('epoch')
plt.ylabel('accuracy')

# 그래프를 표시합니다.
plt.show()

# %%
# 테스트 결과를 출력합니다.
score = model.evaluate(X_test, y_test)
print('Test accuracy:', score[1])
